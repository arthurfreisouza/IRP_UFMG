# %%
import warnings
import random
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
pd.set_option('future.no_silent_downcasting', True)
warnings.filterwarnings("ignore", category=UserWarning)

# %%
df = pd.read_csv("wdbc.data")
column_names = [
    "ID", "Diagnosis", "radius1", "texture1", "perimeter1", "area1", "smoothness1", "compactness1", 
    "concavity1", "concave_points1", "symmetry1", "fractal_dimension1", 
    "radius2", "texture2", "perimeter2", "area2", "smoothness2", "compactness2", 
    "concavity2", "concave_points2", "symmetry2", "fractal_dimension2", 
    "radius3", "texture3", "perimeter3", "area3", "smoothness3", "compactness3", 
    "concavity3", "concave_points3", "symmetry3", "fractal_dimension3"
]
df.columns = column_names
df.head()
# Out:
#          ID Diagnosis  radius1  texture1  perimeter1   area1  smoothness1  \
# 0    842517         M    20.57     17.77      132.90  1326.0      0.08474
# 1  84300903         M    19.69     21.25      130.00  1203.0      0.10960
# 2  84348301         M    11.42     20.38       77.58   386.1      0.14250
# 3  84358402         M    20.29     14.34      135.10  1297.0      0.10030
# 4    843786         M    12.45     15.70       82.57   477.1      0.12780
#
#    compactness1  concavity1  concave_points1  ...  radius3  texture3  \
# 0       0.07864      0.0869          0.07017  ...    24.99     23.41
# 1       0.15990      0.1974          0.12790  ...    23.57     25.53
# 2       0.28390      0.2414          0.10520  ...    14.91     26.50
# 3       0.13280      0.1980          0.10430  ...    22.54     16.67
# 4       0.17000      0.1578          0.08089  ...    15.47     23.75
#
#    perimeter3   area3  smoothness3  compactness3  concavity3  concave_points3  \
# 0      158.80  1956.0       0.1238        0.1866      0.2416           0.1860
# 1      152.50  1709.0       0.1444        0.4245      0.4504           0.2430
# 2       98.87   567.7       0.2098        0.8663      0.6869           0.2575
# 3      152.20  1575.0       0.1374        0.2050      0.4000           0.1625
# 4      103.40   741.6       0.1791        0.5249      0.5355           0.1741
#
#    symmetry3  fractal_dimension3
# 0     0.2750             0.08902
# 1     0.3613             0.08758
# 2     0.6638             0.17300
# 3     0.2364             0.07678
# 4     0.3985             0.12440
#
# [5 rows x 32 columns]

# %%
df.drop(["ID"], axis = 1, inplace = True)

# %%
print(f"The dataframe consists of {df.shape[0]} rows and {df.shape[1]} columns.")
# Out:
# The dataframe consists of 568 rows and 31 columns.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568 entries, 0 to 567
# Data columns (total 31 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Diagnosis           568 non-null    object
#  1   radius1             568 non-null    float64
#  2   texture1            568 non-null    float64
#  3   perimeter1          568 non-null    float64
#  4   area1               568 non-null    float64
#  5   smoothness1         568 non-null    float64
#  6   compactness1        568 non-null    float64
#  7   concavity1          568 non-null    float64
#  8   concave_points1     568 non-null    float64
#  9   symmetry1           568 non-null    float64
#  10  fractal_dimension1  568 non-null    float64
#  11  radius2             568 non-null    float64
#  12  texture2            568 non-null    float64
#  13  perimeter2          568 non-null    float64
#  14  area2               568 non-null    float64
#  15  smoothness2         568 non-null    float64
#  16  compactness2        568 non-null    float64
#  17  concavity2          568 non-null    float64
#  18  concave_points2     568 non-null    float64
#  19  symmetry2           568 non-null    float64
#  20  fractal_dimension2  568 non-null    float64
#  21  radius3             568 non-null    float64
#  22  texture3            568 non-null    float64
#  23  perimeter3          568 non-null    float64
#  24  area3               568 non-null    float64
#  25  smoothness3         568 non-null    float64
#  26  compactness3        568 non-null    float64
#  27  concavity3          568 non-null    float64
#  28  concave_points3     568 non-null    float64
#  29  symmetry3           568 non-null    float64
#  30  fractal_dimension3  568 non-null    float64
# dtypes: float64(30), object(1)
# memory usage: 137.7+ KB

# %%
df.describe()
# Out:
#           radius1    texture1  perimeter1        area1  smoothness1  \
# count  568.000000  568.000000  568.000000   568.000000   568.000000
# mean    14.120491   19.305335   91.914754   654.279754     0.096321
# std      3.523416    4.288506   24.285848   351.923751     0.014046
# min      6.981000    9.710000   43.790000   143.500000     0.052630
# 25%     11.697500   16.177500   75.135000   420.175000     0.086290
# 50%     13.355000   18.855000   86.210000   548.750000     0.095865
# 75%     15.780000   21.802500  103.875000   782.625000     0.105300
# max     28.110000   39.280000  188.500000  2501.000000     0.163400
#
#        compactness1  concavity1  concave_points1   symmetry1  \
# count    568.000000  568.000000       568.000000  568.000000
# mean       0.104036    0.088427         0.048746    0.181055
# std        0.052355    0.079294         0.038617    0.027319
# min        0.019380    0.000000         0.000000    0.106000
# 25%        0.064815    0.029540         0.020310    0.161900
# 50%        0.092525    0.061400         0.033455    0.179200
# 75%        0.130400    0.129650         0.073730    0.195625
# max        0.345400    0.426800         0.201200    0.304000
#
#        fractal_dimension1  ...    radius3    texture3  perimeter3  \
# count          568.000000  ...  568.00000  568.000000  568.000000
# mean             0.062770  ...   16.25315   25.691919  107.125053
# std              0.007035  ...    4.82232    6.141662   33.474687
# min              0.049960  ...    7.93000   12.020000   50.410000
# 25%              0.057697  ...   13.01000   21.095000   84.102500
# 50%              0.061515  ...   14.96500   25.425000   97.655000
# 75%              0.066120  ...   18.76750   29.757500  125.175000
# max              0.097440  ...   36.04000   49.540000  251.200000
#
#              area3  smoothness3  compactness3  concavity3  concave_points3  \
# count   568.000000   568.000000    568.000000  568.000000       568.000000
# mean    878.578873     0.132316      0.253541    0.271414         0.114341
# std     567.846267     0.022818      0.156523    0.207989         0.065484
# min     185.200000     0.071170      0.027290    0.000000         0.000000
# 25%     514.975000     0.116600      0.146900    0.114475         0.064730
# 50%     685.550000     0.131300      0.211850    0.226550         0.099840
# 75%    1073.500000     0.146000      0.337600    0.381400         0.161325
# max    4254.000000     0.222600      1.058000    1.252000         0.291000
#
#         symmetry3  fractal_dimension3
# count  568.000000          568.000000
# mean     0.289776            0.083884
# std      0.061508            0.018017
# min      0.156500            0.055040
# 25%      0.250350            0.071412
# 50%      0.282050            0.080015
# 75%      0.317675            0.092065
# max      0.663800            0.207500
#
# [8 rows x 30 columns]

# %%
df["Diagnosis"] = df["Diagnosis"].replace({"M": 1, "B": -1}) # Tumor Maligno = 1, Tumor Benigno = -1

# %%
df["Diagnosis"].value_counts()
# Out:
# Diagnosis
# -1    357
# 1     211
# Name: count, dtype: int64

# %% [markdown]
# ##### As we can see, in the dataset there are 211 bad cases and 357 good cases.

# %%
import seaborn as sns
corr_matrix = df.corr()

plt.figure(figsize = (20, 8))
sns.heatmap(corr_matrix, annot = True)
plt.plot()
# Out:
# []

# %%
def remove_high_corr(corr_matrix, threshold):
    pos = []
    columns = corr_matrix.columns
    
    for i in range(corr_matrix.shape[0]):
        for j in range(i + 1, corr_matrix.shape[1]):
            if np.abs(corr_matrix.iloc[i, j]) >= threshold :
                pos.append((columns[i], columns[j], corr_matrix.iloc[i, j]))
    return pos

high_corr_col = remove_high_corr(corr_matrix = corr_matrix, threshold = 0.95)

# %%
for c1, c2, val in high_corr_col:
    print(f"The columns {c1} and {c2} has a high correlation of : {round(val, 3)}.")
# Out:
# The columns radius1 and perimeter1 has a high correlation of : 0.998.
# The columns radius1 and area1 has a high correlation of : 0.987.
# The columns radius1 and radius3 has a high correlation of : 0.97.
# The columns radius1 and perimeter3 has a high correlation of : 0.966.
# The columns perimeter1 and area1 has a high correlation of : 0.987.
# The columns perimeter1 and radius3 has a high correlation of : 0.97.
# The columns perimeter1 and perimeter3 has a high correlation of : 0.971.
# The columns area1 and radius3 has a high correlation of : 0.963.
# The columns area1 and perimeter3 has a high correlation of : 0.96.
# The columns area1 and area3 has a high correlation of : 0.96.
# The columns radius2 and perimeter2 has a high correlation of : 0.973.
# The columns radius2 and area2 has a high correlation of : 0.951.
# The columns radius3 and perimeter3 has a high correlation of : 0.994.
# The columns radius3 and area3 has a high correlation of : 0.984.
# The columns perimeter3 and area3 has a high correlation of : 0.977.

# %%
def label_corr(corr_matrix, threshold):
    pos = []
    columns  = corr_matrix.columns
    label_col = corr_matrix.columns.get_loc("Diagnosis")
    for i in range(corr_matrix.shape[0]):
        if (np.abs(corr_matrix.iloc[i, label_col]) >= threshold)  and (i != label_col):
           pos.append((columns[i], corr_matrix.iloc[i, label_col]))
    return pos

label_high = label_corr(corr_matrix = corr_matrix, threshold = 0.75)

for c1, val in label_high:
    print(f"The column {c1} has a big correlation with the label of {round(val, 3)}")
# Out:
# The column concave_points1 has a big correlation with the label of 0.776
# The column radius3 has a big correlation with the label of 0.776
# The column perimeter3 has a big correlation with the label of 0.782
# The column concave_points3 has a big correlation with the label of 0.793

# %%
# Randomizing my model.

df = df.sample(frac = 1).reset_index(drop = True)
df
# Out:
#     Diagnosis  radius1  texture1  perimeter1  area1  smoothness1  \
# 0           1    15.61     19.38      100.00  758.6      0.07840
# 1          -1    12.10     17.72       78.07  446.2      0.10290
# 2          -1    14.42     16.54       94.15  641.2      0.09751
# 3           1    15.85     23.95      103.70  782.7      0.08401
# 4           1    14.60     23.29       93.97  664.7      0.08682
# ..        ...      ...       ...         ...    ...          ...
# 563        -1    11.89     17.36       76.20  435.6      0.12250
# 564        -1    12.31     16.52       79.19  470.9      0.09172
# 565         1    12.83     22.33       85.26  503.2      0.10880
# 566        -1    14.81     14.70       94.66  680.7      0.08472
# 567        -1    11.04     14.93       70.67  372.7      0.07987
#
#      compactness1  concavity1  concave_points1  symmetry1  ...  radius3  \
# 0         0.05616     0.04209          0.02847     0.1547  ...    17.91
# 1         0.09758     0.04783          0.03326     0.1937  ...    13.56
# 2         0.11390     0.08007          0.04223     0.1912  ...    16.67
# 3         0.10020     0.09938          0.05364     0.1847  ...    16.84
# 4         0.06636     0.08390          0.05271     0.1627  ...    15.79
# ..            ...         ...              ...        ...  ...      ...
# 563       0.07210     0.05929          0.07404     0.2015  ...    12.40
# 564       0.06829     0.03372          0.02272     0.1720  ...    14.11
# 565       0.17990     0.16950          0.06861     0.2123  ...    15.20
# 566       0.05016     0.03416          0.02541     0.1659  ...    15.61
# 567       0.07079     0.03546          0.02074     0.2003  ...    12.09
#
#      texture3  perimeter3  area3  smoothness3  compactness3  concavity3  \
# 0       31.67      115.90  988.6       0.1084       0.18070     0.22600
# 1       25.80       88.33  559.5       0.1432       0.17730     0.16030
# 2       21.51      111.40  862.1       0.1294       0.33710     0.37550
# 3       27.66      112.00  876.5       0.1131       0.19240     0.23220
# 4       31.71      102.20  758.2       0.1312       0.15810     0.26750
# ..        ...         ...    ...          ...           ...         ...
# 563     18.99       79.46  472.4       0.1359       0.08368     0.07153
# 564     23.21       89.71  611.1       0.1176       0.18430     0.17030
# 565     30.15      105.30  706.0       0.1777       0.53430     0.62820
# 566     17.58      101.70  760.2       0.1139       0.10110     0.11010
# 567     20.83       79.73  447.1       0.1095       0.19820     0.15530
#
#      concave_points3  symmetry3  fractal_dimension3
# 0            0.08568     0.2683             0.06829
# 1            0.06266     0.3049             0.07081
# 2            0.14140     0.3053             0.08764
# 3            0.11190     0.2809             0.06287
# 4            0.13590     0.2477             0.06836
# ..               ...        ...                 ...
# 563          0.08946     0.2220             0.06033
# 564          0.08660     0.2618             0.07609
# 565          0.19770     0.3407             0.12430
# 566          0.07955     0.2334             0.06142
# 567          0.06754     0.3202             0.07287
#
# [568 rows x 31 columns]

# %% [markdown]
# # SVM CODE USING SKLEARN :

# %%
labels = np.array(df["Diagnosis"])
features = np.array(df.drop(["Diagnosis"], axis = 1))

# %%
# Scaling the features : 
from sklearn.preprocessing import StandardScaler, MinMaxScaler

scaler = MinMaxScaler()
#scaler = StandardScaler()

features = scaler.fit_transform(features)

# %% [markdown]
# ### Now i will build a classifier :

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size = 0.3)

y_train = pd.to_numeric(y_train, errors='coerce')
y_test = pd.to_numeric(y_test, errors='coerce')

# %%
labels_train, counts_train = np.unique(y_train, return_counts = True)

for key, value in zip(labels_train, counts_train):
    if key == 1:
        freq1 = value
    else:
        freq2 = value
    print(f"In class {key} has {value} samples.")
# Out:
# In class -1 has 247 samples.
# In class 1 has 150 samples.

# %%
labels_test, counts_test = np.unique(y_test, return_counts = True)

for key, value in zip(labels_test, counts_test):
    print(f"In class {key} has {value} samples.")
# Out:
# In class -1 has 110 samples.
# In class 1 has 61 samples.

# %%
import time
# Building my SVM classifier
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV

svm = SVC()
c_grid = np.arange(start = 0.01, stop = 2, step = 0.01) # C values for Grid.
kern_type = ["linear", "poly", "rbf", "sigmoid"] # Kernel types for grid
parameters = {"C" : c_grid, "kernel" : kern_type}

start_time = time.time()

GS = GridSearchCV(svm, param_grid = parameters, cv = 10) # Creating my own grid.
GS.fit(X_train, y_train)

end_time = time.time()
print(f"The best accuracy was {GS.best_score_} with the parameters {GS.best_params_}")
# Out:
# The best accuracy was 0.9697435897435897 with the parameters {'C': 0.09, 'kernel': 'poly'}

# %%
best_C = GS.best_params_["C"]
best_Kernel = GS.best_params_["kernel"]

# %%
print(f"Execution time: {end_time - start_time} seconds")
# Out:
# Execution time: 38.2138397693634 seconds

# %%
best_svm = SVC(C = best_C, kernel = best_Kernel, probability = True) # Creating a SVM with the best parameters.
best_svm.fit(X_train, y_train)
pred_val_svm = best_svm.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm_svm = confusion_matrix(y_test, pred_val_svm)
display = ConfusionMatrixDisplay(confusion_matrix = cm_svm)
display.plot()
plt.show()

# %%
from sklearn.metrics import classification_report

report = classification_report(y_test, pred_val_svm)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.64      1.00      0.78       110
#            1       0.00      0.00      0.00        61
#
#     accuracy                           0.64       171
#    macro avg       0.32      0.50      0.39       171
# weighted avg       0.41      0.64      0.50       171

# %%
from sklearn.metrics import roc_curve, auc

pred_proba = best_svm.predict_proba(X_test)[:, 1]

fpr, tpr, thresholds = roc_curve(y_test, pred_proba)

roc_auc = auc(fpr, tpr)

# %%
pred_proba

# %%
# Plot the ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', label='ROC curve (area = {:.2f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], color='red', linestyle='--')  # Diagonal line
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.grid()
plt.show()

# %% [markdown]
# # KNN with code i did by hand:

# %%
def gaussian_kernel(distance, bandwidth=1.0):
    distance = np.asarray(distance)  # Ensure distance is an array
    return np.exp(- (distance ** 2) / (2 * bandwidth ** 2)) / np.sqrt(2 * np.pi)

# %%
def knn_altered_classify(matrix, freq1, freq2, labels, new_points, k, h):
    ret = []
    
    # Check input shapes
    if matrix.shape[0] != labels.shape[0]:
        raise ValueError("The number of samples in the matrix and labels must match.")
    
    for new_point in new_points:
        # Calculate the distances to all points
        distances = np.linalg.norm(matrix - new_point, axis=1)

        # Create weights based on class frequencies
        class_labels = np.unique(labels)
        weights = np.zeros_like(distances)

        # Assign weights based on the class frequencies
        for label in class_labels:
            mask = labels == label
            weights[mask] = freq1 if label == 1 else freq2  # Use appropriate frequencies based on the label

        # Apply frequency weights to distances
        distances *= weights
        
        # Get the indices of the k nearest neighbors
        nearest_indices = np.argsort(distances)[:k]
        
        # Calculate weights using the Gaussian kernel
        nearest_points = distances[nearest_indices]
        kernel_weights = gaussian_kernel(distance=nearest_points, bandwidth=h)

        # Get the labels of the nearest points
        points = labels[nearest_indices]

        # Calculate weighted sum of the labels
        weighted_sum = np.sum(points * kernel_weights)

        # Classify based on weighted sum
        ret.append(1 if weighted_sum >= 0 else -1)

    return ret

# %%
def CV_knn(df, CV, k, h):
    size_samples = df.shape[0] // CV
    df = df.sample(frac=1, random_state=0).reset_index(drop=True)

    # Convert feature columns to numeric
    df.iloc[:, :-1] = df.iloc[:, :-1].apply(pd.to_numeric, errors='coerce')

    y = df["Diagnosis"].values
    df.drop(columns=["Diagnosis"], inplace=True)
    acc = 0

    try:
        for i in range(CV):
            test_indices = range(size_samples * i, size_samples * (i + 1))
            y_test = y[test_indices]
            X_test = df.iloc[test_indices, :].values
            
            # Create train sets by excluding test indices
            y_train = np.delete(y, test_indices, axis=0)
            X_train = df.drop(test_indices).values
            
            labels_train, counts_train = np.unique(y_train, return_counts=True)
            
            freq1, freq2 = 0, 0
            for key, value in zip(labels_train, counts_train):
                if key == 1:
                    freq1 = value
                elif key == -1:
                    freq2 = value
            
            # Ensure the classifier function returns valid predictions
            pred = np.array(knn_altered_classify(matrix=X_train, freq1=freq1, freq2=freq2, labels=y_train,
                                                  new_points=X_test, k=k, h=h))
            


            pred = pred.astype(int)
            y_test = y_test.astype(int)
            acc += accuracy_score(y_test, pred)

        return acc / CV
            
    except Exception as error:
        print(f"The error {error} is happening.")
        raise

# %%
start = time.time()
k = 25
h = 1000
arr_GS = []
for i in range(1, k + 1):
    arr_GS.append(CV_knn(df = df, CV = 10, k = i, h = h))

max_pos = 0
for i in range(len(arr_GS)):
    if arr_GS[i] >= arr_GS[max_pos]:
        max_pos = i

finish = time.time()
print(f"Using k = {max_pos} I had the best accuracy that was: {arr_GS[max_pos]}")
# Out:
# Using k = 24 I had the best accuracy that was: 0.9000000000000001

# %%
print(f"The time was {finish - start}")
# Out:
# The time was 3.150268077850342

# %%
pred_knn = knn_altered_classify(matrix = X_train, freq1 = freq1, freq2 = freq2, labels = y_train, new_points = X_test,
                                k = max_pos, h = h)

# %%
print(f"A acurácia do knn é {accuracy_score(y_test, pred_knn)}")
# Out:
# A acurácia do knn é 0.7777777777777778

# %%
cm_knn = confusion_matrix(y_test, pred_knn)
display = ConfusionMatrixDisplay(confusion_matrix = cm_knn)
display.plot()
plt.show()

# %%
report = classification_report(y_test, pred_knn)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#           -1       1.00      0.65      0.79       110
#            1       0.62      1.00      0.76        61
#
#     accuracy                           0.78       171
#    macro avg       0.81      0.83      0.78       171
# weighted avg       0.86      0.78      0.78       171
